# %% [markdown]
# # Data Cleaning & Augmentation

# %% [markdown]
# ## Load Wine Review Data

# %% [markdown]
# Libraries

# %%
import os
import pandas as pd
import numpy as np
import kagglehub

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Source: Kaggle [Wine Reviews](https://www.kaggle.com/datasets/zynicide/wine-reviews)

# %%
# Download latest version
path = kagglehub.dataset_download("christopheiv/winemagdata130k")
fname = 'winemag-data-130k-v2.csv'
reviews = pd.read_csv(os.path.join(path, fname), index_col=0)
reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %% [markdown]
# # Data Cleanup

# %% [markdown]
# ## Drop columns that are not useful
#
# See [wine_review-initial_data_exploration.ipynb](wine_review-initial_data_exploration.ipynb) for explanation.

# %%
# drop columns that are not useful
reviews.drop(columns=['designation', 'region_2', 'taster_twitter_handle'], inplace=True)
reviews.head()
# Out:
#     country                                        description  points  price  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...      87    NaN
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      87   15.0
# 2        US  Tart and snappy, the flavors of lime flesh and...      87   14.0
# 3        US  Pineapple rind, lemon pith and orange blossom ...      87   13.0
# 4        US  Much like the regular bottling from 2012, this...      87   65.0
#
#             province             region_1         taster_name  \
# 0  Sicily & Sardinia                 Etna       Kerin O’Keefe
# 1              Douro                  NaN          Roger Voss
# 2             Oregon    Willamette Valley        Paul Gregutt
# 3           Michigan  Lake Michigan Shore  Alexander Peartree
# 4             Oregon    Willamette Valley        Paul Gregutt
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos
# 2            Rainstorm
# 3           St. Julian
# 4         Sweet Cheeks

# %% [markdown]
# ## Reduce the dataset
#
# Focus on the top $50$ wine varieties reviewed, from countries with more than $200$ reviews.

# %%
n_varieries = 50
top_varieties = set(reviews.groupby('variety')[['title']].count().rename(columns={'title': 'count'}).reset_index().sort_values('count', ascending=False).head(n_varieries).variety.unique())
np.array(list(top_varieties))
# Out:
# array(['Zinfandel', 'Carmenère', 'Portuguese Red', 'Verdejo',
#        'Tempranillo', 'Garnacha', 'Rhône-style White Blend',
#        'Champagne Blend', 'Sangiovese', 'Grüner Veltliner',
#        'Sauvignon Blanc', 'Cabernet Franc', 'Bordeaux-style White Blend',
#        'Moscato', 'Grenache', 'Aglianico', 'Sparkling Blend', 'Riesling',
#        'Pinot Gris', 'Corvina, Rondinella, Molinara', 'Merlot',
#        'Portuguese White', 'Rhône-style Red Blend', 'Pinot Noir',
#        'Nebbiolo', 'Tempranillo Blend', 'Glera', 'Sauvignon',
#        'Gewürztraminer', 'Port', 'Albariño', "Nero d'Avola", 'Shiraz',
#        'White Blend', 'Gamay', 'Rosé', 'Pinot Grigio', 'Chardonnay',
#        'Red Blend', 'Sangiovese Grosso', 'Chenin Blanc', 'Syrah',
#        'Viognier', 'Barbera', 'Pinot Blanc', 'Melon', 'Malbec',
#        'Petite Sirah', 'Cabernet Sauvignon', 'Bordeaux-style Red Blend'],
#       dtype='<U29')

# %%
cut_off = 200
top_countries = set(reviews.groupby('country')[['title']].count().rename(columns={'title': 'count'}).reset_index().sort_values('count', ascending=False).query(f'count > {cut_off}').country.unique())
np.array(list(top_countries))
# Out:
# array(['Argentina', 'Israel', 'Australia', 'Austria', 'Italy', 'Chile',
#        'US', 'Greece', 'Germany', 'Spain', 'South Africa', 'France',
#        'New Zealand', 'Canada', 'Portugal'], dtype='<U12')

# %%
# reviews from the top countries and top wine varieties
reduced = reviews[reviews.country.isin(top_countries) & reviews.variety.isin(top_varieties)].copy()
reduced
# Out:
#          country                                        description  points  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...      87
# 1       Portugal  This is ripe and fruity, a wine that is smooth...      87
# 2             US  Tart and snappy, the flavors of lime flesh and...      87
# 3             US  Pineapple rind, lemon pith and orange blossom ...      87
# 4             US  Much like the regular bottling from 2012, this...      87
# ...          ...                                                ...     ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...      90
# 129967        US  Citation is given as much as a decade of bottl...      90
# 129968    France  Well-drained gravel soil gives this wine its c...      90
# 129969    France  A dry style of Pinot Gris, this is crisp with ...      90
# 129970    France  Big, rich and off-dry, this is powered by inte...      90
#
#         price           province             region_1         taster_name  \
# 0         NaN  Sicily & Sardinia                 Etna       Kerin O’Keefe
# 1        15.0              Douro                  NaN          Roger Voss
# 2        14.0             Oregon    Willamette Valley        Paul Gregutt
# 3        13.0           Michigan  Lake Michigan Shore  Alexander Peartree
# 4        65.0             Oregon    Willamette Valley        Paul Gregutt
# ...       ...                ...                  ...                 ...
# 129966   28.0              Mosel                  NaN  Anna Lee C. Iijima
# 129967   75.0             Oregon               Oregon        Paul Gregutt
# 129968   30.0             Alsace               Alsace          Roger Voss
# 129969   32.0             Alsace               Alsace          Roger Voss
# 129970   21.0             Alsace               Alsace          Roger Voss
#
#                                                     title         variety  \
# 0                       Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1           Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2           Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3       St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4       Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
# ...                                                   ...             ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef) 2013 ...        Riesling
# 129967                  Citation 2004 Pinot Noir (Oregon)      Pinot Noir
# 129968  Domaine Gresser 2013 Kritt Gewurztraminer (Als...  Gewürztraminer
# 129969      Domaine Marcel Deiss 2012 Pinot Gris (Alsace)      Pinot Gris
# 129970  Domaine Schoffit 2012 Lieu-dit Harth Cuvée Car...  Gewürztraminer
#
#                                           winery
# 0                                        Nicosia
# 1                            Quinta dos Avidagos
# 2                                      Rainstorm
# 3                                     St. Julian
# 4                                   Sweet Cheeks
# ...                                          ...
# 129966  Dr. H. Thanisch (Erben Müller-Burggraef)
# 129967                                  Citation
# 129968                           Domaine Gresser
# 129969                      Domaine Marcel Deiss
# 129970                          Domaine Schoffit
#
# [114592 rows x 10 columns]

# %% [markdown]
# # Data Augmentation

# %% [markdown]
# ### Extract vintage year from `title`

# %%
import re

title_pattern = re.compile(r'\D(19[0-9]{2}|20[0-9]{2})')

# extract vintage year from title, if it exists
def vintage(title):
  m = title_pattern.findall(title)
  if len(m) > 0:
    m = title_pattern.findall(title)
    m.sort()
    return int(m[-1])
  return None

# %%
reduced['year'] = reduced.title.apply(vintage)
reduced.head()
# Out:
#     country                                        description  points  price  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...      87    NaN
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      87   15.0
# 2        US  Tart and snappy, the flavors of lime flesh and...      87   14.0
# 3        US  Pineapple rind, lemon pith and orange blossom ...      87   13.0
# 4        US  Much like the regular bottling from 2012, this...      87   65.0
#
#             province             region_1         taster_name  \
# 0  Sicily & Sardinia                 Etna       Kerin O’Keefe
# 1              Douro                  NaN          Roger Voss
# 2             Oregon    Willamette Valley        Paul Gregutt
# 3           Michigan  Lake Michigan Shore  Alexander Peartree
# 4             Oregon    Willamette Valley        Paul Gregutt
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#                 winery    year
# 0              Nicosia  2013.0
# 1  Quinta dos Avidagos  2011.0
# 2            Rainstorm  2013.0
# 3           St. Julian  2013.0
# 4         Sweet Cheeks  2012.0

# %% [markdown]
# ### Derive `style` of Wine from `variety`
#
# See [Learn Wine With The 9 Major Styles
# ](https://winefolly.com/tips/the-9-major-wine-styles/) for explanation

# %%
styles = {
  'full_red': [
    'Syrah', 'Shiraz','Cabernet Sauvignon','Monastrell','Malbec','Montepulciano','Aglianico','Dolcetto','Rhône-style White Blend',
    'Petite Sirah','Nebbiolo','Tempranillo','Nero d\'Avola','Sagrantino','Tannat','Zinfandel','Tempranillo Blend','Bordeaux-style Red Blend',

  ],
  'medium_red': [
    'Sangiovese','Grenache','Merlot','Negroamaro','Barbera','Cabernet Franc','Valpolicella','Corvina, Rondinella, Molinara',
    'Sangiovese Grosso', 'Carmenère', 'Rhône-style Red Blend','Red Blend',
    'Portuguese Red','Garnacha',
  ],
  'light_red': ['Pinot Noir','Cinsault','Gamay','Ciliegiolo','Freisa','Schiava','Brachetto',],
  'rose': ['Rosé', 'Garnacha Rosé', 'Côtes du Rhône Rosé', 'Provence Rosé', 'Sangiovese Rosé', 'Mourvèdre Rosé', 'Pinot Noir Rosé'],
  'full_white': ['Chardonnay','Sémillon','Viognier','Marsanne',],
  'light_white': [
    'Albariño','Garganega','Grüner Veltliner','Pinot Gris','Pinot Grigio','Sauvignon Blanc',
    'Verdicchio','Verdejo','Vermentino', 'Melon','Pinot Blanc','Bordeaux-style White Blend',
    'White Blend','Portuguese White'
  ],
  'aromatic_white': ['Chenin Blanc','Gewürztraminer','Muscat Blanc','Moscato','Riesling','Torrontés','Glera', 'Sauvignon'],
  'dessert': ['Port','Sherry','Madeira','Late Harvest Wines','Noble Rot Wines',],
  'sparkling': ['Sparkling Blend', 'Champagne Blend', 'Champagne','Cava','Prosecco','Metodo Classico','Sparkling Wine','Sekt','Lambrusco',],
}

def classify_style(variety: str) -> str:
  for style in styles:
    if variety in styles[style]:
      return style
  return None


reduced['wine_style'] = reduced.variety.apply(classify_style)
reduced.head()
# Out:
#     country                                        description  points  price  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...      87    NaN
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      87   15.0
# 2        US  Tart and snappy, the flavors of lime flesh and...      87   14.0
# 3        US  Pineapple rind, lemon pith and orange blossom ...      87   13.0
# 4        US  Much like the regular bottling from 2012, this...      87   65.0
#
#             province             region_1         taster_name  \
# 0  Sicily & Sardinia                 Etna       Kerin O’Keefe
# 1              Douro                  NaN          Roger Voss
# 2             Oregon    Willamette Valley        Paul Gregutt
# 3           Michigan  Lake Michigan Shore  Alexander Peartree
# 4             Oregon    Willamette Valley        Paul Gregutt
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#                 winery    year      wine_style
# 0              Nicosia  2013.0     light_white
# 1  Quinta dos Avidagos  2011.0      medium_red
# 2            Rainstorm  2013.0     light_white
# 3           St. Julian  2013.0  aromatic_white
# 4         Sweet Cheeks  2012.0       light_red

# %%
# count of reviews by style
assert reduced.wine_style.value_counts().sum() == reduced.shape[0], "some varieties could not be classified into a style"
reduced.wine_style.value_counts().to_frame()
# Out:
#                 count
# wine_style
# full_red        33725
# medium_red      23461
# light_white     14704
# light_red       14235
# full_white      12665
# aromatic_white   8129
# rose             3533
# sparkling        3472
# dessert           668

# %% [markdown]
# **Simpler classification of type of wine**

# %%
# define the white wine varieties
white = {
  'Chardonnay', 'Riesling', 'Sauvignon Blanc', 'White Blend', 'Pinot Gris', 'Grüner Veltliner', 'Portuguese White', 
  'Bordeaux-style White Blend', 'Pinot Grigio', 'Gewürztraminer', 'Viognier', 'Glera', 'Chenin Blanc', 'Albariño', 
  'Pinot Blanc', 'Rhône-style White Blend', 'Moscato', 'Sauvignon', 'Verdejo', 'Melon'
}

# verify that white wine varieties are valid
assert white.issubset(top_varieties), 'invalid white wine variety'

# verify that rose wine varieties are valid
rose = {'Rosé'}
assert rose.issubset(top_varieties), 'invalid rose wine variety'

# define the sparkling wine varieties
sparkling = {'Sparkling Blend', 'Champagne Blend'}

# verify that sparkling wine varieties are valid
assert sparkling.issubset(top_varieties), 'invalid sparkling wine variety'

# verify that dessert wine varieties are valid
dessert = {'Port'}
assert dessert.issubset(top_varieties), 'invalid dessert wine variety'

# remaining wines are all red wines
red = top_varieties - white  - rose - sparkling - dessert

# verify that red wine varieties are valid
assert red.union(white).union(sparkling).union(dessert).union(rose) == top_varieties, 'invalid red wine variety'

np.array(list(red))
# Out:
# array(['Zinfandel', 'Carmenère', 'Portuguese Red', 'Tempranillo',
#        'Garnacha', 'Tempranillo Blend', "Nero d'Avola", 'Sangiovese',
#        'Shiraz', 'Gamay', 'Cabernet Franc', 'Red Blend', 'Grenache',
#        'Aglianico', 'Sangiovese Grosso', 'Corvina, Rondinella, Molinara',
#        'Syrah', 'Merlot', 'Barbera', 'Rhône-style Red Blend', 'Malbec',
#        'Petite Sirah', 'Pinot Noir', 'Cabernet Sauvignon',
#        'Bordeaux-style Red Blend', 'Nebbiolo'], dtype='<U29')

# %%
# set the wine type
reduced.loc[reduced.variety.isin(red), 'type'] = 'red'
reduced.loc[reduced.variety.isin(rose), 'type'] = 'rose'
reduced.loc[reduced.variety.isin(white), 'type'] = 'white'
reduced.loc[reduced.variety.isin(sparkling), 'type'] = 'sparkling'
reduced.loc[reduced.variety.isin(dessert), 'type'] = 'dessert'
reduced.head()
# Out:
#     country                                        description  points  price  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...      87    NaN
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      87   15.0
# 2        US  Tart and snappy, the flavors of lime flesh and...      87   14.0
# 3        US  Pineapple rind, lemon pith and orange blossom ...      87   13.0
# 4        US  Much like the regular bottling from 2012, this...      87   65.0
#
#             province             region_1         taster_name  \
# 0  Sicily & Sardinia                 Etna       Kerin O’Keefe
# 1              Douro                  NaN          Roger Voss
# 2             Oregon    Willamette Valley        Paul Gregutt
# 3           Michigan  Lake Michigan Shore  Alexander Peartree
# 4             Oregon    Willamette Valley        Paul Gregutt
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#                 winery    year      wine_style   type
# 0              Nicosia  2013.0     light_white  white
# 1  Quinta dos Avidagos  2011.0      medium_red    red
# 2            Rainstorm  2013.0     light_white  white
# 3           St. Julian  2013.0  aromatic_white  white
# 4         Sweet Cheeks  2012.0       light_red    red

# %%
# count of reviews by type
assert reduced.type.value_counts().sum() == reduced.shape[0], "some varieties could not be classified into a type"
reduced.type.value_counts().to_frame()
# Out:
#            count
# type
# red        70996
# white      35923
# rose        3533
# sparkling   3472
# dessert      668

# %% [markdown]
# ### Derive Quality of Wine from `points`

# %%
reduced['quality'] = reduced.points.apply(lambda points: 'medium' if points < 90 else 'high')
reduced.head()
# Out:
#     country                                        description  points  price  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...      87    NaN
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      87   15.0
# 2        US  Tart and snappy, the flavors of lime flesh and...      87   14.0
# 3        US  Pineapple rind, lemon pith and orange blossom ...      87   13.0
# 4        US  Much like the regular bottling from 2012, this...      87   65.0
#
#             province             region_1         taster_name  \
# 0  Sicily & Sardinia                 Etna       Kerin O’Keefe
# 1              Douro                  NaN          Roger Voss
# 2             Oregon    Willamette Valley        Paul Gregutt
# 3           Michigan  Lake Michigan Shore  Alexander Peartree
# 4             Oregon    Willamette Valley        Paul Gregutt
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#                 winery    year      wine_style   type quality
# 0              Nicosia  2013.0     light_white  white  medium
# 1  Quinta dos Avidagos  2011.0      medium_red    red  medium
# 2            Rainstorm  2013.0     light_white  white  medium
# 3           St. Julian  2013.0  aromatic_white  white  medium
# 4         Sweet Cheeks  2012.0       light_red    red  medium

# %% [markdown]
# ### Derive the *old* vs *new* *world wine* classification from `country`

# %%
# assign top countries to old and new world classification
old_world = {'France','Italy','Spain','Portugal','Austria','Germany','Israel','Greece'}
new_world = {'US','Chile','Argentina','Australia','New Zealand','South Africa','Canada'}

reduced['classification'] = reduced.country.apply(lambda country: 'Old World' if country in old_world else 'New World')
reduced.head()
# Out:
#     country                                        description  points  price  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...      87    NaN
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      87   15.0
# 2        US  Tart and snappy, the flavors of lime flesh and...      87   14.0
# 3        US  Pineapple rind, lemon pith and orange blossom ...      87   13.0
# 4        US  Much like the regular bottling from 2012, this...      87   65.0
#
#             province             region_1         taster_name  \
# 0  Sicily & Sardinia                 Etna       Kerin O’Keefe
# 1              Douro                  NaN          Roger Voss
# 2             Oregon    Willamette Valley        Paul Gregutt
# 3           Michigan  Lake Michigan Shore  Alexander Peartree
# 4             Oregon    Willamette Valley        Paul Gregutt
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#                 winery    year      wine_style   type quality classification
# 0              Nicosia  2013.0     light_white  white  medium      Old World
# 1  Quinta dos Avidagos  2011.0      medium_red    red  medium      Old World
# 2            Rainstorm  2013.0     light_white  white  medium      New World
# 3           St. Julian  2013.0  aromatic_white  white  medium      New World
# 4         Sweet Cheeks  2012.0       light_red    red  medium      New World

# %%
# count of reviews by classification
reduced.classification.value_counts().to_frame()
# Out:
#                 count
# classification
# New World       63750
# Old World       50842

# %% [markdown]
# ### Derive Location of Wine from `province`, `region_1`, and `region_2`

# %% [markdown]
# **Use `region_1` value when province includes country name, like** *Northern Spain*

# %%
reduced['location'] = reduced.apply(lambda row: row.region_1 if row.country in row.province else row.province, axis=1)
reduced.head()
# Out:
#     country                                        description  points  price  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...      87    NaN
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      87   15.0
# 2        US  Tart and snappy, the flavors of lime flesh and...      87   14.0
# 3        US  Pineapple rind, lemon pith and orange blossom ...      87   13.0
# 4        US  Much like the regular bottling from 2012, this...      87   65.0
#
#             province             region_1         taster_name  \
# 0  Sicily & Sardinia                 Etna       Kerin O’Keefe
# 1              Douro                  NaN          Roger Voss
# 2             Oregon    Willamette Valley        Paul Gregutt
# 3           Michigan  Lake Michigan Shore  Alexander Peartree
# 4             Oregon    Willamette Valley        Paul Gregutt
#
#                                                title         variety  \
# 0                  Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1      Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2      Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
# 3  St. Julian 2013 Reserve Late Harvest Riesling ...        Riesling
# 4  Sweet Cheeks 2012 Vintner's Reserve Wild Child...      Pinot Noir
#
#                 winery    year      wine_style   type quality classification  \
# 0              Nicosia  2013.0     light_white  white  medium      Old World
# 1  Quinta dos Avidagos  2011.0      medium_red    red  medium      Old World
# 2            Rainstorm  2013.0     light_white  white  medium      New World
# 3           St. Julian  2013.0  aromatic_white  white  medium      New World
# 4         Sweet Cheeks  2012.0       light_red    red  medium      New World
#
#             location
# 0  Sicily & Sardinia
# 1              Douro
# 2             Oregon
# 3           Michigan
# 4             Oregon

# %% [markdown]
# **Replace provinces with value** *Other* **with `region_1` value**

# %%
reduced.loc[reduced.location == 'Other', 'location'] = reduced.loc[reduced.location == 'Other', 'region_1']
reduced[reduced.province == 'Other'].head()
# Out:
#         country                                        description  points  \
# 16    Argentina  Baked plum, molasses, balsamic vinegar and che...      87
# 245   Argentina  Not exactly a world-class white wine but at le...      85
# 785   Argentina  This is a highly particular, funky blend of 85...      90
# 914   Argentina  Smashed berry aromas are backed by earth and t...      87
# 1493  Argentina  Light, floral and somewhat out of the mold. Fl...      85
#
#       price province          region_1        taster_name  \
# 16     30.0    Other          Cafayate  Michael Schachner
# 245    12.0    Other          San Juan  Michael Schachner
# 785    25.0    Other             Salta  Michael Schachner
# 914    20.0    Other          San Juan  Michael Schachner
# 1493   12.0    Other  Calchaquí Valley  Michael Schachner
#
#                                                   title     variety  \
# 16           Felix Lavaque 2010 Felix Malbec (Cafayate)      Malbec
# 245   Finca Las Moras 2007 Reserve Chardonnay (San J...  Chardonnay
# 785             San Pedro de Yacochuya 2012 Red (Salta)   Red Blend
# 914      Graffigna 2012 Grand Reserve Malbec (San Juan)      Malbec
# 1493  Michel Torino 2007 Coleccion Chardonnay (Calch...  Chardonnay
#
#                       winery    year  wine_style   type quality  \
# 16             Felix Lavaque  2010.0    full_red    red  medium
# 245          Finca Las Moras  2007.0  full_white  white  medium
# 785   San Pedro de Yacochuya  2012.0  medium_red    red    high
# 914                Graffigna  2012.0    full_red    red  medium
# 1493           Michel Torino  2007.0  full_white  white  medium
#
#      classification          location
# 16        New World          Cafayate
# 245       New World          San Juan
# 785       New World             Salta
# 914       New World          San Juan
# 1493      New World  Calchaquí Valley

# %% [markdown]
# **Replace provinces like** *Sicily & Sardinia* **with `region_1` value**

# %%
reduced.loc[reduced.province.str.contains('&'), 'location'] = reduced.loc[reduced.province.str.contains('&'), 'region_1']
reduced[reduced.province.str.contains('&')].head()
# Out:
#    country                                        description  points  price  \
# 0    Italy  Aromas include tropical fruit, broom, brimston...      87    NaN
# 22   Italy  Delicate aromas recall white flower and citrus...      87   19.0
# 24   Italy  Aromas of prune, blackcurrant, toast and oak c...      87   35.0
# 26   Italy  Pretty aromas of yellow flower and stone fruit...      87   13.0
# 27   Italy  Aromas recall ripe dark berry, toast and a whi...      87   10.0
#
#              province         region_1    taster_name  \
# 0   Sicily & Sardinia             Etna  Kerin O’Keefe
# 22  Sicily & Sardinia          Sicilia  Kerin O’Keefe
# 24  Sicily & Sardinia          Sicilia  Kerin O’Keefe
# 26  Sicily & Sardinia  Terre Siciliane  Kerin O’Keefe
# 27  Sicily & Sardinia  Terre Siciliane  Kerin O’Keefe
#
#                                                 title       variety  \
# 0                   Nicosia 2013 Vulkà Bianco  (Etna)   White Blend
# 22  Baglio di Pianetto 2007 Ficiligno White (Sicilia)   White Blend
# 24        Canicattì 2009 Aynat Nero d'Avola (Sicilia)  Nero d'Avola
# 26       Stemmari 2013 Dalila White (Terre Siciliane)   White Blend
# 27       Stemmari 2013 Nero d'Avola (Terre Siciliane)  Nero d'Avola
#
#                 winery    year   wine_style   type quality classification  \
# 0              Nicosia  2013.0  light_white  white  medium      Old World
# 22  Baglio di Pianetto  2007.0  light_white  white  medium      Old World
# 24           Canicattì  2009.0     full_red    red  medium      Old World
# 26            Stemmari  2013.0  light_white  white  medium      Old World
# 27            Stemmari  2013.0     full_red    red  medium      Old World
#
#            location
# 0              Etna
# 22          Sicilia
# 24          Sicilia
# 26  Terre Siciliane
# 27  Terre Siciliane

# %% [markdown]
# **Drop the `province` and `region_1` fields**

# %%
reduced.drop(columns=['province', 'region_1'], inplace=True)
reduced.head()
# Out:
#     country                                        description  points  price  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...      87    NaN
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      87   15.0
# 2        US  Tart and snappy, the flavors of lime flesh and...      87   14.0
# 3        US  Pineapple rind, lemon pith and orange blossom ...      87   13.0
# 4        US  Much like the regular bottling from 2012, this...      87   65.0
#
#           taster_name                                              title  \
# 0       Kerin O’Keefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1          Roger Voss      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2        Paul Gregutt      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3  Alexander Peartree  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4        Paul Gregutt  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery    year      wine_style   type quality  \
# 0     White Blend              Nicosia  2013.0     light_white  white  medium
# 1  Portuguese Red  Quinta dos Avidagos  2011.0      medium_red    red  medium
# 2      Pinot Gris            Rainstorm  2013.0     light_white  white  medium
# 3        Riesling           St. Julian  2013.0  aromatic_white  white  medium
# 4      Pinot Noir         Sweet Cheeks  2012.0       light_red    red  medium
#
#   classification  location
# 0      Old World      Etna
# 1      Old World     Douro
# 2      New World    Oregon
# 3      New World  Michigan
# 4      New World    Oregon

# %% [markdown]
# ## Set missing `taster_name` to *Unknown*

# %%
print(f'{reduced[reduced.taster_name.isna()].shape[0]:,d}', 'reviews don\'t have a taster specified.')
reduced[reduced.taster_name.isna()].head()
# Out:
# 23,397 reviews don't have a taster specified.
#    country                                        description  points  price  \
# 31   Italy  Merlot and Nero d'Avola form the base for this...      86    NaN
# 32   Italy  Part of the extended Calanìca series, this Gri...      86    NaN
# 33      US  Rustic and dry, this has flavors of berries, c...      86   50.0
# 34      US  This shows a tart, green gooseberry flavor tha...      86   20.0
# 37   Italy  This concentrated Cabernet offers aromas of cu...      86   21.0
#
#    taster_name                                              title  \
# 31         NaN  Duca di Salaparuta 2010 Calanìca Nero d'Avola-...
# 32         NaN  Duca di Salaparuta 2011 Calanìca Grillo-Viogni...
# 33         NaN  Envolve 2010 Puma Springs Vineyard Red (Dry Cr...
# 34         NaN       Envolve 2011 Sauvignon Blanc (Sonoma Valley)
# 37         NaN  Feudi del Pisciotto 2010 Missoni Cabernet Sauv...
#
#                variety               winery    year   wine_style   type  \
# 31           Red Blend   Duca di Salaparuta  2010.0   medium_red    red
# 32         White Blend   Duca di Salaparuta  2011.0  light_white  white
# 33           Red Blend              Envolve  2010.0   medium_red    red
# 34     Sauvignon Blanc              Envolve  2011.0  light_white  white
# 37  Cabernet Sauvignon  Feudi del Pisciotto  2010.0     full_red    red
#
#    quality classification    location
# 31  medium      Old World     Sicilia
# 32  medium      Old World     Sicilia
# 33  medium      New World  California
# 34  medium      New World  California
# 37  medium      Old World     Sicilia

# %% [markdown]
# **Replace** *NaN* **values in `taster_name` with the value** *Unknown*

# %%
reduced.loc[reduced.taster_name.isna(), 'taster_name'] = 'Unknown'
reduced[reduced.taster_name.isna()]
# Out:
# Empty DataFrame
# Columns: [country, description, points, price, taster_name, title, variety, winery, year, wine_style, type, quality, classification, location]
# Index: []

# %% [markdown]
# ## Derive `Price Band` classification from `price`

# %%
reduced.loc[reduced.price <= 12, 'band'] = 'value'
reduced.loc[(reduced.price >= 13) & (reduced.price <= 16), 'band'] = 'popular'
reduced.loc[(reduced.price >= 17) & (reduced.price <= 22), 'band'] = 'premium'
reduced.loc[(reduced.price >= 23) & (reduced.price <= 30), 'band'] = 'super'
reduced.loc[(reduced.price >= 31) & (reduced.price <= 50), 'band'] = 'ultra'
reduced.loc[(reduced.price >= 51) & (reduced.price <= 100), 'band'] = 'luxury'
reduced.loc[(reduced.price >= 101) & (reduced.price <= 200), 'band'] = 'super luxury'
reduced.loc[(reduced.price >= 201), 'band'] = 'icon'

reduced.band.value_counts().to_frame()
# Out:
#               count
# band
# ultra         25153
# super         19570
# premium       18880
# luxury        15510
# popular       13827
# value         10528
# super luxury   2521
# icon            643

# %%
reduced.head()
# Out:
#     country                                        description  points  price  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...      87    NaN
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      87   15.0
# 2        US  Tart and snappy, the flavors of lime flesh and...      87   14.0
# 3        US  Pineapple rind, lemon pith and orange blossom ...      87   13.0
# 4        US  Much like the regular bottling from 2012, this...      87   65.0
#
#           taster_name                                              title  \
# 0       Kerin O’Keefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1          Roger Voss      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2        Paul Gregutt      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3  Alexander Peartree  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4        Paul Gregutt  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery    year      wine_style   type quality  \
# 0     White Blend              Nicosia  2013.0     light_white  white  medium
# 1  Portuguese Red  Quinta dos Avidagos  2011.0      medium_red    red  medium
# 2      Pinot Gris            Rainstorm  2013.0     light_white  white  medium
# 3        Riesling           St. Julian  2013.0  aromatic_white  white  medium
# 4      Pinot Noir         Sweet Cheeks  2012.0       light_red    red  medium
#
#   classification  location     band
# 0      Old World      Etna      NaN
# 1      Old World     Douro  popular
# 2      New World    Oregon  popular
# 3      New World  Michigan  popular
# 4      New World    Oregon   luxury

# %% [markdown]
# `Price Band` will need to be imputed along with `price`.

# %% [markdown]
# # Organize columns
# Organize the columns in groups that represent the role to column plays in the reviews.

# %%
# subject columns: columns that identify the wine being reviewed
subject_cols = ['title', 'winery', 'variety', 'wine_style', 'type', 'year', 'price', 'band']      # what is being reviewed
location_cols = ['country', 'location', 'classification']                                         # where it is from
taster_cols = ['taster_name']                                                                     # who is reviewing it
review_cols = ['description', 'points', 'quality']                                                # the review the wine got

# verify that the column groupings match the columns of the reduced dataset
assert set(subject_cols + location_cols + taster_cols + review_cols) == set(reduced.columns)

# %% [markdown]
# # Evaluate the reduced dataset

# %%
reduced.info()
reduced.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 114592 entries, 0 to 129970
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   country         114592 non-null  object
#  1   description     114592 non-null  object
#  2   points          114592 non-null  int64
#  3   price           106632 non-null  float64
#  4   taster_name     114592 non-null  object
#  5   title           114592 non-null  object
#  6   variety         114592 non-null  object
#  7   winery          114592 non-null  object
#  8   year            110687 non-null  float64
#  9   wine_style      114592 non-null  object
#  10  type            114592 non-null  object
#  11  quality         114592 non-null  object
#  12  classification  114592 non-null  object
#  13  location        114431 non-null  object
#  14  band            106632 non-null  object
# dtypes: float64(2), int64(1), object(12)
# memory usage: 14.0+ MB
#     country                                        description  points  price  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...      87    NaN
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      87   15.0
# 2        US  Tart and snappy, the flavors of lime flesh and...      87   14.0
# 3        US  Pineapple rind, lemon pith and orange blossom ...      87   13.0
# 4        US  Much like the regular bottling from 2012, this...      87   65.0
#
#           taster_name                                              title  \
# 0       Kerin O’Keefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1          Roger Voss      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2        Paul Gregutt      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3  Alexander Peartree  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4        Paul Gregutt  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery    year      wine_style   type quality  \
# 0     White Blend              Nicosia  2013.0     light_white  white  medium
# 1  Portuguese Red  Quinta dos Avidagos  2011.0      medium_red    red  medium
# 2      Pinot Gris            Rainstorm  2013.0     light_white  white  medium
# 3        Riesling           St. Julian  2013.0  aromatic_white  white  medium
# 4      Pinot Noir         Sweet Cheeks  2012.0       light_red    red  medium
#
#   classification  location     band
# 0      Old World      Etna      NaN
# 1      Old World     Douro  popular
# 2      New World    Oregon  popular
# 3      New World  Michigan  popular
# 4      New World    Oregon   luxury

# %% [markdown]
# ## Missing Values

# %%
reduced.isna().sum()
# Out:
# country              0
# description          0
# points               0
# price             7960
# taster_name          0
# title                0
# variety              0
# winery               0
# year              3905
# wine_style           0
# type                 0
# quality              0
# classification       0
# location           161
# band              7960
# dtype: int64

# %% [markdown]
# **Drop missing year values**

# %%
reduced = reduced[reduced.year.notna()].copy()
reduced.year = reduced.year.astype(int)
reduced.info()
reduced.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 110687 entries, 0 to 129970
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   country         110687 non-null  object
#  1   description     110687 non-null  object
#  2   points          110687 non-null  int64
#  3   price           103131 non-null  float64
#  4   taster_name     110687 non-null  object
#  5   title           110687 non-null  object
#  6   variety         110687 non-null  object
#  7   winery          110687 non-null  object
#  8   year            110687 non-null  int64
#  9   wine_style      110687 non-null  object
#  10  type            110687 non-null  object
#  11  quality         110687 non-null  object
#  12  classification  110687 non-null  object
#  13  location        110552 non-null  object
#  14  band            103131 non-null  object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 13.5+ MB
# country              0
# description          0
# points               0
# price             7556
# taster_name          0
# title                0
# variety              0
# winery               0
# year                 0
# wine_style           0
# type                 0
# quality              0
# classification       0
# location           135
# band              7556
# dtype: int64

# %%
reduced[reduced.location.isna()].country.unique()
# Out:
# array(['Chile', 'South Africa', 'Italy', 'France', 'Israel',
#        'New Zealand', 'Germany', 'Greece', 'Austria', 'Portugal', 'Spain',
#        'Australia'], dtype=object)

# %% [markdown]
# **Drop missing location values**

# %%
reduced = reduced[reduced.location.notna()].copy()
reduced.info()
reduced.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 110552 entries, 0 to 129970
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   country         110552 non-null  object
#  1   description     110552 non-null  object
#  2   points          110552 non-null  int64
#  3   price           103006 non-null  float64
#  4   taster_name     110552 non-null  object
#  5   title           110552 non-null  object
#  6   variety         110552 non-null  object
#  7   winery          110552 non-null  object
#  8   year            110552 non-null  int64
#  9   wine_style      110552 non-null  object
#  10  type            110552 non-null  object
#  11  quality         110552 non-null  object
#  12  classification  110552 non-null  object
#  13  location        110552 non-null  object
#  14  band            103006 non-null  object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 13.5+ MB
# country              0
# description          0
# points               0
# price             7546
# taster_name          0
# title                0
# variety              0
# winery               0
# year                 0
# wine_style           0
# type                 0
# quality              0
# classification       0
# location             0
# band              7546
# dtype: int64

# %% [markdown]
# Missing `price` and `band` values will be imputed from the data.

# %% [markdown]
# ## Duplicate Values

# %%
duplicate_reviews = reduced.groupby(['title', 'description'])[['points']].count().rename(columns={'points': 'count'}).sort_values('count', ascending=False).query('count > 1').reset_index()
duplicate_reviews
# Out:
#                                                   title  \
# 0          Pulenta Estate 2010 La Flor Malbec (Mendoza)
# 1     Bodegas Vidal Soblechero 2007 Viña Clavidor Ce...
# 2     Bodegas Paniza 2015 Sleever Garnacha Rosé (Car...
# 3     Oxford Landing 2008 GSM Grenache-Shiraz-Mourvè...
# 4     Trinchero 2009 Mary's Vineyard Sauvignon Blanc...
# ...                                                 ...
# 8422  Rasa 2014 Plus One Kiona Vineyard Cabernet Sau...
# 8423         Atwater 2008 Cabernet Franc (Finger Lakes)
# 8424       Deutz 2010 Blanc de Blancs Brut  (Champagne)
# 8425   Atwater 2008 Cuvée Brut Sparkling (Finger Lakes)
# 8426          Höpler 2013 Grüner Veltliner (Burgenland)
#
#                                             description  count
# 0     Cherry and berry aromas are standard and good....      2
# 1     Unlike the regular Clavidor, this old-vines wi...      2
# 2     Packed in a pink bottle, this Garnacha rosé op...      2
# 3     This blend of 45% Grenache, 28% Shiraz and 27%...      2
# 4     A wonderful Sauvignon Blanc, bone dry and tart...      2
# ...                                                 ...    ...
# 8422  Although it's 100% varietal and comes from one...      2
# 8423  Forward and fruity, with loads of sweet cherry...      2
# 8424  This wine is still young, reveling in its brig...      2
# 8425  Dusty mineral notes mingle alongside pretty fl...      2
# 8426  A hint of lime and green pear peel, a touch of...      2
#
# [8427 rows x 3 columns]

# %% [markdown]
# Examine one of the duplicates

# %%
reduced.query(f'title == "{duplicate_reviews.iloc[0,0]}" and description == "{duplicate_reviews.iloc[0,1]}"')
# Out:
#          country                                        description  points  \
# 24330  Argentina  Cherry and berry aromas are standard and good....      85
# 73564  Argentina  Cherry and berry aromas are standard and good....      85
#
#        price        taster_name                                         title  \
# 24330   16.0  Michael Schachner  Pulenta Estate 2010 La Flor Malbec (Mendoza)
# 73564   16.0  Michael Schachner  Pulenta Estate 2010 La Flor Malbec (Mendoza)
#
#       variety          winery  year wine_style type quality classification  \
# 24330  Malbec  Pulenta Estate  2010   full_red  red  medium      New World
# 73564  Malbec  Pulenta Estate  2010   full_red  red  medium      New World
#
#                location     band
# 24330  Mendoza Province  popular
# 73564  Mendoza Province  popular

# %% [markdown]
# **Drop Duplicates**

# %%
reduced.drop_duplicates(subset=['title', 'description'], inplace=True)
reduced.groupby(['title', 'description'])[['points']].count().rename(columns={'points': 'count'}).sort_values('count', ascending=False).query('count > 1').reset_index()
# Out:
# Empty DataFrame
# Columns: [title, description, count]
# Index: []

# %%
# verify that one of the duplicate reviews remains in the dataset
reduced.query(f'title == "{duplicate_reviews.iloc[0,0]}" and description == "{duplicate_reviews.iloc[0,1]}"')
# Out:
#          country                                        description  points  \
# 24330  Argentina  Cherry and berry aromas are standard and good....      85
#
#        price        taster_name                                         title  \
# 24330   16.0  Michael Schachner  Pulenta Estate 2010 La Flor Malbec (Mendoza)
#
#       variety          winery  year wine_style type quality classification  \
# 24330  Malbec  Pulenta Estate  2010   full_red  red  medium      New World
#
#                location     band
# 24330  Mendoza Province  popular

# %%
reduced.info()
reduced.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 102125 entries, 0 to 129970
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   country         102125 non-null  object
#  1   description     102125 non-null  object
#  2   points          102125 non-null  int64
#  3   price           95062 non-null   float64
#  4   taster_name     102125 non-null  object
#  5   title           102125 non-null  object
#  6   variety         102125 non-null  object
#  7   winery          102125 non-null  object
#  8   year            102125 non-null  int64
#  9   wine_style      102125 non-null  object
#  10  type            102125 non-null  object
#  11  quality         102125 non-null  object
#  12  classification  102125 non-null  object
#  13  location        102125 non-null  object
#  14  band            95062 non-null   object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 12.5+ MB
#     country                                        description  points  price  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...      87    NaN
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      87   15.0
# 2        US  Tart and snappy, the flavors of lime flesh and...      87   14.0
# 3        US  Pineapple rind, lemon pith and orange blossom ...      87   13.0
# 4        US  Much like the regular bottling from 2012, this...      87   65.0
#
#           taster_name                                              title  \
# 0       Kerin O’Keefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1          Roger Voss      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2        Paul Gregutt      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3  Alexander Peartree  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4        Paul Gregutt  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery  year      wine_style   type quality  \
# 0     White Blend              Nicosia  2013     light_white  white  medium
# 1  Portuguese Red  Quinta dos Avidagos  2011      medium_red    red  medium
# 2      Pinot Gris            Rainstorm  2013     light_white  white  medium
# 3        Riesling           St. Julian  2013  aromatic_white  white  medium
# 4      Pinot Noir         Sweet Cheeks  2012       light_red    red  medium
#
#   classification  location     band
# 0      Old World      Etna      NaN
# 1      Old World     Douro  popular
# 2      New World    Oregon  popular
# 3      New World  Michigan  popular
# 4      New World    Oregon   luxury

# %% [markdown]
# ## Outliers

# %%
fig, ax = plt.subplots(figsize=(15, 2))
ax = sns.boxplot(reduced, x='year', orient='h')
ax.set_title('Distribution of vintage years')
ax.set_xlabel('Year')
plt.show()

# %%
reduced.query('year < 2000')
# Out:
#        country                                        description  points  \
# 367      Chile  Aromas of mint, berry syrup and dense, lemony ...      88
# 369      Italy  This medium-weight wine flows effortlessly fro...      88
# 370         US  Mint again, with earth and tobacco; one taster...      88
# 375      Italy  A soft, ripe wine that manages to showcase tob...      88
# 388         US  Delicate and complex, a cool climate wine with...      88
# ...        ...                                                ...     ...
# 127800   Italy  Bright and intense berry aromas lead into a ta...      85
# 128681  France  A Blanc de Blancs, from 100% Chardonnay, Deutz...      95
# 128688  France  There is no question this is a food Champagne....      94
# 128695  France  A beautifully fine, elegant wine, the acidity ...      94
# 128697  France  With all the signature acidity of the 1996 vin...      94
#
#         price        taster_name  \
# 367      10.0  Michael Schachner
# 369      21.0     Joe Czerwinski
# 370     160.0            Unknown
# 375      40.0            Unknown
# 388      25.0         Roger Voss
# ...       ...                ...
# 127800   18.0  Michael Schachner
# 128681    NaN         Roger Voss
# 128688  170.0         Roger Voss
# 128695  167.0         Roger Voss
# 128697  180.0         Roger Voss
#
#                                                     title             variety  \
# 367     De Martino 1999 Reserva de la Familia Carmenèr...           Carmenère
# 369              Ronco del Gelso 1999 Chardonnay (Friuli)          Chardonnay
# 370     Sebastiani 1991 Cherryblock Vineyard Cabernet ...  Cabernet Sauvignon
# 375      Valiano 1997 Vino in Musica Sangiovese (Toscana)          Sangiovese
# 388     Kynsi 1999 Paragon Vineyard Pinot Noir (Edna V...          Pinot Noir
# ...                                                   ...                 ...
# 127800          Viticcio 1998 Riserva  (Chianti Classico)          Sangiovese
# 128681  Deutz 1999 Amour de Deutz Brut Chardonnay (Cha...          Chardonnay
# 128688  Deutz 1999 Cuvée William Deutz Rosé Brut  (Cha...     Champagne Blend
# 128695   Deutz 1999 Cuvée William Deutz Brut  (Champagne)     Champagne Blend
# 128697  Bruno Paillard 1996 Blanc de Blancs Brut Chard...          Chardonnay
#
#                  winery  year  wine_style       type quality classification  \
# 367          De Martino  1999  medium_red        red  medium      New World
# 369     Ronco del Gelso  1999  full_white      white  medium      Old World
# 370          Sebastiani  1991    full_red        red  medium      New World
# 375             Valiano  1997  medium_red        red  medium      Old World
# 388               Kynsi  1999   light_red        red  medium      New World
# ...                 ...   ...         ...        ...     ...            ...
# 127800         Viticcio  1998  medium_red        red  medium      Old World
# 128681            Deutz  1999  full_white      white    high      Old World
# 128688            Deutz  1999   sparkling  sparkling    high      Old World
# 128695            Deutz  1999   sparkling  sparkling    high      Old World
# 128697   Bruno Paillard  1996  full_white      white    high      Old World
#
#             location          band
# 367     Maipo Valley         value
# 369           Friuli       premium
# 370       California  super luxury
# 375          Tuscany         ultra
# 388       California         super
# ...              ...           ...
# 127800       Tuscany       premium
# 128681     Champagne           NaN
# 128688     Champagne  super luxury
# 128695     Champagne  super luxury
# 128697     Champagne  super luxury
#
# [1587 rows x 15 columns]

# %% [markdown]
# **Ignore wine vintages before 2000**

# %%
reduced = reduced.query('year >= 2000').copy()
reduced.info()
reduced.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100538 entries, 0 to 129970
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   country         100538 non-null  object
#  1   description     100538 non-null  object
#  2   points          100538 non-null  int64
#  3   price           93522 non-null   float64
#  4   taster_name     100538 non-null  object
#  5   title           100538 non-null  object
#  6   variety         100538 non-null  object
#  7   winery          100538 non-null  object
#  8   year            100538 non-null  int64
#  9   wine_style      100538 non-null  object
#  10  type            100538 non-null  object
#  11  quality         100538 non-null  object
#  12  classification  100538 non-null  object
#  13  location        100538 non-null  object
#  14  band            93522 non-null   object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 12.3+ MB
#     country                                        description  points  price  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...      87    NaN
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      87   15.0
# 2        US  Tart and snappy, the flavors of lime flesh and...      87   14.0
# 3        US  Pineapple rind, lemon pith and orange blossom ...      87   13.0
# 4        US  Much like the regular bottling from 2012, this...      87   65.0
#
#           taster_name                                              title  \
# 0       Kerin O’Keefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1          Roger Voss      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2        Paul Gregutt      Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3  Alexander Peartree  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4        Paul Gregutt  Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery  year      wine_style   type quality  \
# 0     White Blend              Nicosia  2013     light_white  white  medium
# 1  Portuguese Red  Quinta dos Avidagos  2011      medium_red    red  medium
# 2      Pinot Gris            Rainstorm  2013     light_white  white  medium
# 3        Riesling           St. Julian  2013  aromatic_white  white  medium
# 4      Pinot Noir         Sweet Cheeks  2012       light_red    red  medium
#
#   classification  location     band
# 0      Old World      Etna      NaN
# 1      Old World     Douro  popular
# 2      New World    Oregon  popular
# 3      New World  Michigan  popular
# 4      New World    Oregon   luxury

# %% [markdown]
# # Data Cleansing Summary
#
# - dropped `designation`, `region_2` and `taster_twitter_handle` columns
# - reduced the dataset to only include reviews on the top $50$ wine varieties from countries with more than $200$ reviews
# - further reduced the dataset to reviews of wines from vintages that are from $2000$ or more recent.
# - extracted vintage `year` from `title`
# - derived `type` and `wine_style` from `variety`
# - derived `quality` from `points`
# - derived price `band` from `price`
# - derived the *old* vs. *new* world classification from the `country` field
# - derived `location` column from the `province`, `region_1`, `region_2` columns
# - set missing `taster_name` to *Unknown*
# - dropped remaining data missing `location` and `year`
# - dropped duplicate reviews: reviews with duplicate`title` & `description`
#
# Started with $129,971$ reviews, and ended up with $100,538$ reviews after data cleansing and data preparation.

# %% [markdown]
# # Saved the cleansed dataset

# %%
reduced.to_parquet('files/wine_review.parquet.gzip',compression='gzip')

# %% [markdown]
# # Next Step
# - [exploratory data analysis](wine_review-eda.ipynb)
